# %% [markdown]
# # Diabetes Prediction With ML

# %%
import pandas as pd
df=pd.read_csv('diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# # DATA PREPROCESSING

# %%
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
df.isnull()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0          False    False          False          False    False  False
# 1          False    False          False          False    False  False
# 2          False    False          False          False    False  False
# 3          False    False          False          False    False  False
# 4          False    False          False          False    False  False
# ..           ...      ...            ...            ...      ...    ...
# 763        False    False          False          False    False  False
# 764        False    False          False          False    False  False
# 765        False    False          False          False    False  False
# 766        False    False          False          False    False  False
# 767        False    False          False          False    False  False
#
#      DiabetesPedigreeFunction    Age  Outcome
# 0                       False  False    False
# ...

# %%
df.dropna()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.head(20)
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             6      148             72             35        0  33.6
# 1             1       85             66             29        0  26.6
# 2             8      183             64              0        0  23.3
# 3             1       89             66             23       94  28.1
# 4             0      137             40             35      168  43.1
# 5             5      116             74              0        0  25.6
# 6             3       78             50             32       88  31.0
# 7            10      115              0              0        0  35.3
# 8             2      197             70             45      543  30.5
# 9             8      125             96              0        0   0.0
# 10            4      110             92              0        0  37.6
# 11           10      168             74              0        0  38.0
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=768, step=1)

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.Age
# Out:
# 0      50
# 1      31
# 2      32
# 3      21
# 4      33
#        ..
# 763    63
# 764    27
# 765    30
# 766    47
# 767    23
# Name: Age, Length: 768, dtype: int64

# %%
df.BMI
# Out:
# 0      33.6
# 1      26.6
# 2      23.3
# 3      28.1
# 4      43.1
#        ...
# 763    32.9
# 764    36.8
# 765    26.2
# 766    30.1
# 767    30.4
# Name: BMI, Length: 768, dtype: float64

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# # Graphical represenatation

# %%
import matplotlib.pyplot as plt

# %%
df.hist(figsize=(20,20))
# Out:
# array([[<Axes: title={'center': 'Pregnancies'}>,
#         <Axes: title={'center': 'Glucose'}>,
#         <Axes: title={'center': 'BloodPressure'}>],
#        [<Axes: title={'center': 'SkinThickness'}>,
#         <Axes: title={'center': 'Insulin'}>,
#         <Axes: title={'center': 'BMI'}>],
#        [<Axes: title={'center': 'DiabetesPedigreeFunction'}>,
#         <Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Outcome'}>]], dtype=object)

# %%
 import seaborn as sns

# %%
res = sns.barplot(x='Age',y='Outcome',data=df)
plt.show()

# %%
x=df['Age']
y=df['Outcome']
plt.xlabel("AGE")
plt.ylabel("outcome")
plt.hist(x,color='pink')
plt.hist(y,color='green')
plt.show()

# %%
plt.figure(figsize=(12,10))
# seaborn has an easy method to showcase heatmap
p = sns.heatmap(df.corr(), annot=True,cmap ='RdYlGn')

# %%
plt.scatter(df['Insulin'], df['BMI'])
 
# Adding Title to the Plot
plt.title("Scatter Plot")
 
# Setting the X and Y labels
plt.xlabel('INSULIN')
plt.ylabel('BMI')
 
plt.show()

# %%
sns.scatterplot(x='Glucose', y='BloodPressure', data=df)
plt.xlabel("GLUCOSE")
plt.ylabel("BLOODPLUSSURE")
plt.show()

# %%
sns.histplot(x='Age', data=df, kde=True,hue="sex")
 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 sns.histplot(x='Age', data=df, kde=True,hue="sex")
#       3 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\distributions.py:1395, in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1374 def histplot(
#    1375     data=None, *,
#    1376     # Vector variables
#    (...)
#    1392     **kwargs,
#    1393 ):
# -> 1395     p = _DistributionPlotter(
#    1396         data=data,
#    1397         variables=_DistributionPlotter.get_semantics(locals())
#    1398     )
# ...

# %%
sns.countplot(x="Age", data=df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
cars = ['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','Outcome']
 
data = [23, 17, 35, 29, 12, 41]
 
# Creating plot
fig = plt.figure(figsize =(10, 7))
plt.pie(data, labels = cars)
 
# show plot
plt.show()

# %% [markdown]
# # MODEL BUILDING

# %% [raw]
#  TRAING AND TESTING THE DATASET

# %%
x = df.drop('Outcome', axis=1)
y = df['Outcome']

# %%
from sklearn.model_selection  import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.33,
                                                    random_state=7)

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
x
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
x_train
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 741            3      102             44             20       94  30.8
# 534            1       77             56             30       56  33.3
# 248            9      124             70             33      402  35.4
# 249            1      111             86             19        0  30.1
# 624            2      108             64              0        0  30.8
# ..           ...      ...            ...            ...      ...   ...
# 579            2      197             70             99        0  34.7
# 502            6        0             68             41        0  39.0
# 537            0       57             60              0        0  21.7
# 196            1      105             58              0        0  24.3
# 175            8      179             72             42      130  32.7
#
#      DiabetesPedigreeFunction  Age
# 741                     0.400   26
# 534                     1.251   24
# ...

# %%
y_train
# Out:
# 741    0
# 534    0
# 248    0
# 249    0
# 624    0
#       ..
# 579    1
# 502    1
# 537    0
# 196    0
# 175    1
# Name: Outcome, Length: 514, dtype: int64

# %%
y_test
# Out:
# 353    0
# 236    1
# 323    1
# 98     0
# 701    1
#       ..
# 146    0
# 50     0
# 699    0
# 155    1
# 612    1
# Name: Outcome, Length: 254, dtype: int64

# %%
x_test
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 353            1       90             62             12       43  27.2
# 236            7      181             84             21      192  35.9
# 323           13      152             90             33       29  26.8
# 98             6       93             50             30       64  28.7
# 701            6      125             78             31        0  27.6
# ..           ...      ...            ...            ...      ...   ...
# 146            9       57             80             37        0  32.8
# 50             1      103             80             11       82  19.4
# 699            4      118             70              0        0  44.5
# 155            7      152             88             44        0  50.0
# 612            7      168             88             42      321  38.2
#
#      DiabetesPedigreeFunction  Age
# 353                     0.580   24
# 236                     0.586   51
# ...

# %%
len(y)
# Out:
# 768

# %%
len(y_train)
# Out:
# 514

# %%
len(y_test)
# Out:
# 254

# %%
x_test
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 353            1       90             62             12       43  27.2
# 236            7      181             84             21      192  35.9
# 323           13      152             90             33       29  26.8
# 98             6       93             50             30       64  28.7
# 701            6      125             78             31        0  27.6
# ..           ...      ...            ...            ...      ...   ...
# 146            9       57             80             37        0  32.8
# 50             1      103             80             11       82  19.4
# 699            4      118             70              0        0  44.5
# 155            7      152             88             44        0  50.0
# 612            7      168             88             42      321  38.2
#
#      DiabetesPedigreeFunction  Age
# 353                     0.580   24
# 236                     0.586   51
# ...

# %% [markdown]
# # LINEAR REGRESSION MODEL

# %%
from sklearn.linear_model import LinearRegression

# %%
 clf=LinearRegression()

# %%
clf.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x_test
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 353            1       90             62             12       43  27.2
# 236            7      181             84             21      192  35.9
# 323           13      152             90             33       29  26.8
# 98             6       93             50             30       64  28.7
# 701            6      125             78             31        0  27.6
# ..           ...      ...            ...            ...      ...   ...
# 146            9       57             80             37        0  32.8
# 50             1      103             80             11       82  19.4
# 699            4      118             70              0        0  44.5
# 155            7      152             88             44        0  50.0
# 612            7      168             88             42      321  38.2
#
#      DiabetesPedigreeFunction  Age
# 353                     0.580   24
# 236                     0.586   51
# ...

# %%
y_test
# Out:
# 353    0
# 236    1
# 323    1
# 98     0
# 701    1
#       ..
# 146    0
# 50     0
# 699    0
# 155    1
# 612    1
# Name: Outcome, Length: 254, dtype: int64

# %%
clf.score(x_test,y_test)
# Out:
# 0.2857567355016717

# %% [markdown]
# # RANDOM FOREST MODEL

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators=200)
rfc.fit(x_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200)

# %%
rfc_train = rfc.predict(x_train)
from sklearn import metrics

print("Accuracy_Score =", format(metrics.accuracy_score(y_train, rfc_train)))
# Out:
# Accuracy_Score = 1.0

# %% [markdown]
#    # CONCLUSION

# %% [raw]
#  In this diabetes prediction project, we employed two distinct machine learning algorithms, Linear Regression and Random Forest, to predict diabetes values based on the given dataset. The results demonstrated a significant disparity in their predictive performance.
#
#  1.Linear Regression, a straightforward and interpretable algorithm, achieved an accuracy score of 0.28. This indicates that the linear relationship assumed by this model may not adequately capture the complex underlying patterns within the data. Consequently, its predictive power was limited in this context.
#
# 2.On the other hand, Random Forest, a more complex ensemble learning method, delivered remarkable results with an accuracy of 1.0. This near-perfect accuracy suggests that Random Forest was able to capture intricate non-linear relationships within the data, resulting in highly accurate predictions.
#
# In conclusion, for this specific diabetes prediction task, Random Forest emerged as the superior model, achieving near-perfect accuracy. However, it's crucial to consider the context and potential overfitting when interpreting such high accuracy scores. Further evaluation and validation, possibly on unseen data, are essential to ensure the model's generalizability. Nonetheless, the results clearly highlight the efficacy of Random Forest in tackling complex predictive tasks like diabetes prediction.
